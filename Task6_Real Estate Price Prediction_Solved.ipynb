# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn

# %%
import pandas as pd
import sklearn 
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
data= pd.read_csv('Real estate.csv')
data.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# ### Show more information about the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
data.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
data.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
X = data.iloc[:,:-1]
X
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 7 columns]

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y=data['Y house price of unit area']
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create an Estimator object

# %%
model = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
lrm=model.fit(X_train,y_train)

# %% [markdown]
# ### Apply the model

# %%
y_pred=lrm.predict(X_test)
y_pred
# Out:
# array([34.13280763, 47.36181245, 20.89817448, 13.13114541, 43.04430831,
#        34.09388124, 30.84894315, 44.47492616, 38.27213021, 14.29964908,
#        12.41276148, 38.68771499, 31.61749994, 44.94396718, 50.43074598,
#        35.95284236, 44.0412455 , 44.77440747, 30.36956665, 43.40535766,
#        50.74265173, 28.76942487, 39.81103854, 46.39692693, 45.6549232 ,
#        28.0021102 , 31.66357206, 47.38119292, 46.23464332, 15.21723741,
#        33.76107235, 34.80623355, 41.92453517, 44.16646456, 48.00403648,
#        13.52713064, 41.0647064 , 41.01377179, 38.54397944, 13.84580199,
#        39.52197985, 24.90790961, 53.89738321, 36.24053551, 34.50911615,
#        38.62628058, 30.6666834 , 39.22900954, 45.25530607, 34.05465486,
#        11.82731949, 44.44898769, 44.67149267, 13.99930514, 48.93497431,
#        42.10847079, 43.67779841, 39.07038469, 38.04961014, 39.8220716 ,
#        25.18758026, 40.27395458, 34.91517828, 13.05150853, 40.10092215,
#        44.76086232, 39.45780681, 46.96355671, 14.85117702, 39.97190199,
#        47.0253958 ,  9.76118289, 34.14438866, 39.27599503, 48.95621178,
#        37.78548322, 35.66849049, 37.93460832, 40.5301024 , 47.60553712,
#        45.13548114, 41.0229311 , 45.5821952 , 39.57179669, 44.48056538,
#        53.06224665, 47.42415977, 34.80626742, 49.55371944, 17.0156496 ,
#        32.76566369, 50.17249426, 40.82853433, 31.63683634, 47.9092477 ,
#        40.6031299 , 27.72630107, 39.92077488, 50.25676336, 41.40365713,
#        33.7539625 , 46.19158817, 29.93463449, 31.34690959])

# %% [markdown]
# ### Display the coefficients

# %%
lrm.coef_
# Out:
# array([-2.24350051e-03,  5.07360299e+00, -2.40202026e-01, -4.91306916e-03,
#         1.06507867e+00,  2.16239895e+02, -4.02604572e+01])

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
from sklearn.metrics import r2_score

print("r2 score: ",r2_score(y_test,y_pred))
# Out:
# r2 score:  0.6981767502020799

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
x=data['X2 house age']
y=data['Y house price of unit area']

sns.regplot(x=x,y=y,data=data)
# Out:
# <Axes: xlabel='X2 house age', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
x=data['X3 distance to the nearest MRT station']
y=data['Y house price of unit area']
sns.regplot(x=x,y=y,data=data)
# Out:
# <Axes: xlabel='X3 distance to the nearest MRT station', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
x=data['X4 number of convenience stores']
y=data['Y house price of unit area']
sns.regplot(x=x,y=y,data=data)
# Out:
# <Axes: xlabel='X4 number of convenience stores', ylabel='Y house price of unit area'>
